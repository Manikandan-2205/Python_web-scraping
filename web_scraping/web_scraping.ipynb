# %%
from bs4 import BeautifulSoup
import requests, openpyxl
import pandas, numpy

# %%
response = requests.get("https://www.gsmarena.com/makers.php3")
soupe = BeautifulSoup(response.text, 'html.parser')
print(soupe)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>List of all mobile phone brands - GSMArena.com</title>
# <script>
# DESKTOP_BASE_URL = "https://www.gsmarena.com/";
# MOBILE_BASE_URL = "https://m.gsmarena.com/";
# ASSETS_BASE_URL  = "https://fdn.gsmarena.com/vv/assets12/";
# CDN_BASE_URL = "//fdn.gsmarena.com/";
# CDN2_BASE_URL = "//fdn2.gsmarena.com/";
# </script>
# <meta charset="utf-8"/>
# <meta content="width=1060, initial-scale=1.0" name="viewport"/>
# <link href="https://fdn.gsmarena.com/vv/assets12/css/gsmarena.css?v=80" rel="stylesheet"/>
# <link href="https://fdn.gsmarena.com/imgroot/static/favicon.ico" rel="shortcut icon"/>
# <script>
# window["pgGlobalSettings"] = {
#     "global": {
#         "strategy": "include"
#     },
#     "adUnits": []
# };
#
# function addAdUnit(adUnitCode) {
#     window.pgGlobalSettings.adUnits.push({ "adUnitCode": adUnitCode });
# };
#
#
# ...

# %%
mobile = soupe.find("div", class_ = 'st-text').find_all('td')
print(mobile)
# Out:
# [<td><a href="acer-phones-59.php">Acer<br/><span>100 devices</span></a></td>, <td><a href="alcatel-phones-5.php">alcatel<br/><span>409 devices</span></a></td>, <td><a href="allview-phones-88.php">Allview<br/><span>157 devices</span></a></td>, <td><a href="amazon-phones-76.php">Amazon<br/><span>24 devices</span></a></td>, <td><a href="amoi-phones-28.php">Amoi<br/><span>47 devices</span></a></td>, <td><a href="apple-phones-48.php">Apple<br/><span>111 devices</span></a></td>, <td><a href="archos-phones-90.php">Archos<br/><span>43 devices</span></a></td>, <td><a href="asus-phones-46.php">Asus<br/><span>199 devices</span></a></td>, <td><a href="at&amp;t-phones-57.php">AT&amp;T<br/><span>4 devices</span></a></td>, <td><a href="benefon-phones-15.php">Benefon<br/><span>9 devices</span></a></td>, <td><a href="benq-phones-31.php">BenQ<br/><span>35 devices</span></a></td>, <td><a href="benq_siemens-phones-42.php">BenQ-Siemens<br/><span>27 devices</span></a></td>, <td><a href="bird-phones-34.php
# ...

# %%
for phone in mobile:
    phone_name = phone.find('a', href = 'acer-phones-59.php')
    #print(phone_name)
    sheet.append([phone_name])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2 phone_name = phone.find('a', href = 'acer-phones-59.php')
#       3 #print(phone_name)
# ----> 4 sheet.append([phone_name])
#
# File d:\Education Document\jupyter_notebook_word\.venv\Lib\site-packages\openpyxl\worksheet\worksheet.py:670, in Worksheet.append(self, iterable)
#     668             cell.row = row_idx
#     669         else:
# --> 670             cell = Cell(self, row=row_idx, column=col_idx, value=content)
#     671         self._cells[(row_idx, col_idx)] = cell
#     673 elif isinstance(iterable, dict):
#
# File d:\Education Document\jupyter_notebook_word\.venv\Lib\site-packages\openpyxl\cell\cell.py:119, in Cell.__init__(self, worksheet, row, column, value, style_array)
#     117 self.data_type = 'n'
#     118 if value is not None:
# --> 119     self.value = value
# ...

# %%
excel = openpyxl.Workbook()
sheet = excel.active
sheet.title = "phone_name"
sheet.append(['phone_name'])
